# %% [markdown]
# <b><font size="6">Visualizing the EU Emissions Trading System</font></b>
# <br>Where to get your data & how to prepare it.
# <br>Download Data from EU Registry
#
# https://console.cloud.google.com/google/maps-apis/apis/geocoding-backend.googleapis.com/quotas?project=eu-ets

# %%
import pandas as pd
import os
import country_converter as coco
import googlemaps
import xlwings as xw
import numpy as np
import math
import time
import re
from functools import reduce

# %%
def clean_header(df):
    return [c.upper().replace(' ', '_') for c in list(df)]

# %%
dir_ = r'/Users/sebastian/Google Drive/ai_stock_picker/06_eu_ets'

# %%
pth_emissions = os.path.join(dir_, r'verified_emissions_2018_en.xlsx')
pth_installations = os.path.join(dir_, r'stationary_installations_union_registry_phase_iii_en.xlsx')
pth_data_01 = os.path.join(dir_, r'data_01.csv')
pth_data_02 = os.path.join(dir_, r'data_02.csv')
pth_data_03 = os.path.join(dir_, r'data_03.csv')

# %% [markdown]
# # Load Installation Data

# %%
installation = pd.read_excel(pth_installations, skiprows=1)

# %%
installation.columns = clean_header(installation)

# %%
cc = coco.CountryConverter()
iso_2 = list(installation['MS_REGISTRY'].unique())
countries = cc.convert(names =  list(installation['MS_REGISTRY'].unique()), to='name_short')
installation['COUNTRY'] = installation['MS_REGISTRY'].map(dict(zip(iso_2, countries)))

# %%
address_columns = ['CONTACT_ADDRESS_L1', 'CONTACT_CITY', 'COUNTRY']

# %%
installation.shape
# Out:
# (15043, 15)

# %%
installation.dropna(subset=address_columns).shape
# Out:
# (15040, 15)

# %%
for c in address_columns:
    installation[c] = installation[c].astype(str)

# %%
installation['ADDRESS'] = installation[address_columns].agg(', '.join, axis=1)

# %%
unique_locations = pd.DataFrame(installation['ADDRESS'].unique().tolist(), columns=['ADDRESS'])

# %%
some_locations = ['1 Altens Farm Road, Aberdeen, United Kingdom',
                  '1 Angel Lane, London, United Kingdom',
                  '1 Avenue Oscar Lambret, Lille, France',
                  '1 Boulevard Benoît Frachon, Varennes Vauzelles, France',
                  '1 Chemin des Chaux de la Tour, Ensues la Redonne, France',
                  '1 Churchill Place, London, United Kingdom',
                  '1 Decembrie 1918 nr. 146, Caracal, Romania']

# %%
location_chunks = []
chunk_size = 4500
nr_of_records = len(unique_locations)
nr_of_chunks = math.ceil(nr_of_records / chunk_size)

for i in range(nr_of_chunks): 
    location_chunk = unique_locations[i*chunk_size:(i+1)*chunk_size]
    location_chunks.append(location_chunk)

# %% [markdown]
# # Add Longitude & Latitude with Google Maps API

# %% [markdown]
# https://towardsdatascience.com/mapping-messy-addresses-part-1-getting-latitude-and-longitude-8fa7ba792430

# %%
gmaps = googlemaps.Client(key='AIzaSyBh43P4gi3akVBUV83ggJ0X0VylcJXAYgA')

def get_geocode_result(geo_string):

    geocode_result = gmaps.geocode(geo_string)
    # check to see if the result is empty and if so return zeros to indicate unparseable junction value
    if len(geocode_result) > 0:
        locs = geocode_result[0]['geometry']['location']
        return [locs['lat'], locs['lng']]
    else:
        return [0.0, 0.0]

# %%
for location_chunk in location_chunks:
    start_ = time.time()
    
    # Create multiple pandas DataFrame columns from applying a function with multiple returns.
    location_chunk[['LAT','LON']] = location_chunk['ADDRESS'].apply(lambda s: pd.Series(get_geocode_result(s)))
    
    duration = time.time() - start_
    print(duration)
    
    gap = 100 - duration
    if gap > 0:
        time.sleep(gap + 5)
# Out:
# /usr/local/anaconda3/envs/propulsion_env/lib/python3.7/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# 2338.4667751789093
# 2433.7138018608093
# 2086.1263427734375

# %%
location = pd.concat(location_chunks)

# %%
installation = pd.merge(installation, location, how='inner')
# Drop 'INSTALLATION_NAME'
installation.drop('INSTALLATION_NAME', axis=1, inplace=True)

# %% [markdown]
# # Import Emission Data & Join with Installation Data

# %%
emissions = pd.read_excel(pth_emissions, skiprows=13)

# %%
data = pd.merge(emissions, installation, how='inner', left_on=['INSTALLATION_IDENTIFIER', 'REGISTRY_CODE'], right_on=['INSTALLATION_ID', 'MS_REGISTRY'])

# %%
data.to_csv(pth_data_01, '|')

# %%
data_prefix = ['ALLOCATION',
               'ALLOCATION_RESERVE',
               'ALLOCATION_TRANSITIONAL',
               'VERIFIED_EMISSIONS']

# %%
melted_frames = []
for prefix in data_prefix:
    pattern = prefix + '_\d{4}'
    cols = [c for c in data.columns if re.match(pattern, c)]
    df = pd.melt(data.reset_index(),
                 id_vars='index',
                 value_vars=cols,
                 value_name=prefix,
                 var_name='YEAR').rename(columns={'index':'INDEX'})
    df['YEAR'] = df['YEAR'].str.replace(prefix + '_', '').astype(int)
    melted_frames.append(df)

# %%
time_series = reduce(lambda left,right: pd.merge(left,right,how='outer',on=['INDEX','YEAR']), melted_frames)

# %%
cols_installation = ['INSTALLATION_NAME',
                     'ACCOUNT_HOLDER_NAME',
                     'ACTIVITY_TYPE',
                     'CONTACT_CITY',
                     'CONTACT_ADDRESS_L1',
                     'COUNTRY',
                     'LAT',
                     'LON']

#[c for c in data.columns if not any(s in c for s in data_prefix)]
#[cols_installation.remove(c) for c in ['MS_REGISTRY', 'INSTALLATION_ID', 'PERMIT_ID', 'REGISTRY_CODE', 'IDENTIFIER_IN_REG']]
#None

# %%
data_02 = pd.merge(data[cols_installation].reset_index().rename(columns={'index': 'INDEX'}),
                   time_series,
                   how='inner',
                   on='INDEX')

# %%
data_02 = data_02.fillna(0)
# A metric column that contains only 0 and -1's fill cause visualization to crash.
# Hence replace all 0 and -1's to 1's.
# Also some columns contain 'Excluded'
# Actually the percentile slider will return a empty dataframe which cases the crash.
cols = ['ALLOCATION', 'ALLOCATION_RESERVE', 'ALLOCATION_TRANSITIONAL', 'VERIFIED_EMISSIONS']

data_02[cols] = data_02[cols].replace('Excluded',1)

for c in cols:
    data_02[c] = data_02[c].astype(int)

data_02[cols] = data_02[cols].replace({0:1, -1:1})
data_02 = data_02.replace({'nan':'Unknown'})
#data_02[['ALLOCATION', 'ALLOCATION_RESERVE', 'ALLOCATION_TRANSITIONAL', 'VERIFIED_EMISSIONS']].replace(0.0,1, inplace=True)
#data_02[['ALLOCATION', 'ALLOCATION_RESERVE', 'ALLOCATION_TRANSITIONAL', 'VERIFIED_EMISSIONS']].replace(-1,1, inplace=True)

# %%
data_02.head(20)
# Out:
#     INDEX INSTALLATION_NAME ACCOUNT_HOLDER_NAME  \
# 0       0    AGRANA Aschach  AGRANA Stärke GmbH
# 1       0    AGRANA Aschach  AGRANA Stärke GmbH
# 2       0    AGRANA Aschach  AGRANA Stärke GmbH
# 3       0    AGRANA Aschach  AGRANA Stärke GmbH
# 4       0    AGRANA Aschach  AGRANA Stärke GmbH
# 5       0    AGRANA Aschach  AGRANA Stärke GmbH
# 6       0    AGRANA Aschach  AGRANA Stärke GmbH
# 7       0    AGRANA Aschach  AGRANA Stärke GmbH
# 8       0    AGRANA Aschach  AGRANA Stärke GmbH
# 9       0    AGRANA Aschach  AGRANA Stärke GmbH
# 10      0    AGRANA Aschach  AGRANA Stärke GmbH
# 11      1      AGRANA Gmünd  AGRANA Stärke GmbH
# 12      1      AGRANA Gmünd  AGRANA Stärke GmbH
# 13      1      AGRANA Gmünd  AGRANA Stärke GmbH
# 14      1      AGRANA Gmünd  AGRANA Stärke GmbH
# 15      1      AGRANA Gmünd  AGRANA Stärke GmbH
# 16      1      AGRANA Gmünd  AGRANA Stärke GmbH
# 17      1      AGRANA Gmünd  AGRANA Stärke GmbH
# 18      1      AGRANA Gmünd  AGRANA Stärke GmbH
# 19      1      AGRANA Gmünd  AGRANA Stärke GmbH
#
#                            ACTIVITY_TYPE CONTACT_CITY CONTACT_ADDRESS_L1  \
# 0   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 1   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 2   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 3   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 4   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 5   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 6   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 7   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 8   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 9   COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 10  COMBUSTION_OF_FUELS_IN_INSTALLATIONS      Aschach  Raiffeisenweg 2-6
# 11  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
# 12  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
# 13  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
# 14  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
# 15  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
# 16  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
# 17  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
# 18  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
# 19  COMBUSTION_OF_FUELS_IN_INSTALLATIONS        Gmünd   Conrathstrasse 7
#
#     COUNTRY        LAT        LON  YEAR  ALLOCATION  ALLOCATION_RESERVE  \
# 0   Austria  48.363288  14.015714  2018       52651                   1
# 1   Austria  48.363288  14.015714  2017       53656                   1
# 2   Austria  48.363288  14.015714  2016       54659                   1
# 3   Austria  48.363288  14.015714  2015       55662                   1
# 4   Austria  48.363288  14.015714  2014       56666                   1
# 5   Austria  48.363288  14.015714  2013       57669                   1
# 6   Austria  48.363288  14.015714  2012       74854                   1
# 7   Austria  48.363288  14.015714  2011       74854                   1
# 8   Austria  48.363288  14.015714  2010       74854                   1
# 9   Austria  48.363288  14.015714  2009       74854                   1
# 10  Austria  48.363288  14.015714  2008       74854                   1
# 11  Austria  48.763534  14.978751  2018       24384                   1
# 12  Austria  48.763534  14.978751  2017       25326                   1
# 13  Austria  48.763534  14.978751  2016       26279                   1
# 14  Austria  48.763534  14.978751  2015       27245                   1
# 15  Austria  48.763534  14.978751  2014       27565                   1
# 16  Austria  48.763534  14.978751  2013       28705                   1
# 17  Austria  48.763534  14.978751  2012       33837                   1
# 18  Austria  48.763534  14.978751  2011       33837                   1
# 19  Austria  48.763534  14.978751  2010       33837                   1
#
#     ALLOCATION_TRANSITIONAL  VERIFIED_EMISSIONS
# 0                         1               83757
# 1                         1               84100
# 2                         1               81599
# 3                         1               79640
# 4                         1               81011
# 5                         1               82073
# 6                         1               81114
# 7                         1               81065
# 8                         1               81800
# 9                         1               77710
# 10                        1               76343
# 11                        1               40089
# 12                        1               39282
# 13                        1               37500
# 14                        1               35812
# 15                        1               34693
# 16                        1               34683
# 17                        1               36080
# 18                        1               34599
# 19                        1               33695

# %%
# change in last n periods
#data_02.sort_values('YEAR').groupby('INDEX')[cols].pct_change()

# change since first period
data_aux_01 = pd.merge(data_02,
                       data_02.loc[data_02.groupby('INDEX')['YEAR'].idxmin()][['INDEX','YEAR'] + cols],
                       how='left',
                       on=['INDEX'],
                       suffixes=('','_START'))

for c in cols:
    data_aux_01[c + '_PCT_CHANGE'] = (data_aux_01[c] - data_aux_01[c + '_START']) / data_aux_01[c + '_START'] * 100

#data_02[['INDEX','YEAR']+ cols]x
#df['pct'] = df.sort_values('Date').groupby(['Company', 'Group']).Value.pct_change()

# %%
data_03 = data_aux_01

# %%
data_03.to_csv(pth_data_03, '|', index=False)

# %%
df = data_02
value = 'ALLOCATION'

# %%
pd.qcut(df.rank(method='first'), nbins)

# %%
center = 10000

# %%
df['RANK'] = df.groupby(['YEAR'])[value].rank(method='first')

# %%
df.loc[df[value] >= center, 'BIN'] = df[df[value] >= center].groupby(['YEAR'])['RANK'].transform(
    lambda x: pd.qcut(x, 5, labels=range(6,11)))

df.loc[df[value] < center, 'BIN'] = df[df[value] < center].groupby(['YEAR'])['RANK'].transform(
    lambda x: pd.qcut(x, 5, labels=range(1,6)))

# %%
df['BIN'].map({9:['A','B']})
# Out:
#           0    1
# 0         A    B
# 1         A    B
# 2         A    B
# 3         A    B
# 4         A    B
# 5         A    B
# 6         A    B
# 7         A    B
# 8         A    B
# 9         A    B
# 10        A    B
# 11      NaN  NaN
# 12      NaN  NaN
# 13      NaN  NaN
# 14      NaN  NaN
# 15      NaN  NaN
# 16      NaN  NaN
# 17      NaN  NaN
# 18      NaN  NaN
# 19      NaN  NaN
# 20      NaN  NaN
# 21      NaN  NaN
# 22        A    B
# 23        A    B
# 24        A    B
# 25        A    B
# 26        A    B
# 27        A    B
# 28        A    B
# 29        A    B
# ...     ...  ...
# 128340  NaN  NaN
# 128341  NaN  NaN
# 128342  NaN  NaN
# 128343  NaN  NaN
# 128344  NaN  NaN
# 128345  NaN  NaN
# 128346  NaN  NaN
# 128347  NaN  NaN
# 128348  NaN  NaN
# 128349  NaN  NaN
# 128350  NaN  NaN
# 128351  NaN  NaN
# 128352  NaN  NaN
# 128353  NaN  NaN
# 128354  NaN  NaN
# 128355  NaN  NaN
# 128356  NaN  NaN
# 128357  NaN  NaN
# 128358  NaN  NaN
# 128359    A    B
# 128360    A    B
# 128361    A    B
# 128362    A    B
# 128363    A    B
# 128364    A    B
# 128365    A    B
# 128366    A    B
# 128367    A    B
# 128368    A    B
# 128369    A    B
#
# [128370 rows x 2 columns]

# %%
df.loc[df[value] >= center,'BIN'] = pd.qcut(df[df[value] >= center].groupby(['YEAR'])[value].rank(method='first'),
        q=5, retbins=False, labels=[5,4,3,2,1])
df.loc[df[value] < center,'BIN'] = pd.qcut(df[df[value] < center].groupby(['YEAR'])[value].rank(method='first'),
        q=5, retbins=False, labels=[10,9,8,7,6])


df['C'] = df.groupby(['A'])['B'].transform(
                     lambda x: pd.qcut(x, 3, labels=range(1,4)))

# %%
df.sort_values(['YEAR','ALLOCATION'])
# Out:
#         INDEX                                  INSTALLATION_NAME  \
# 65          5                                  AMAG casting GmbH
# 76          6                                  AMAG rolling GmbH
# 98          8                                         Atmosa PSA
# 131        11                             Bernegger Molln Ofen 1
# 142        12                             Bernegger Molln Ofen 2
# 153        13                             Bernegger Molln Ofen 3
# 175        15                Biomasseheizkraftwerk Hall in Tirol
# 186        16                            Boehler Schmiedetechnik
# 197        17          Borealis Agrolinz Melamine Ammoniakanlage
# 208        18     Borealis Agrolinz Melamine Salpetersäureanlage
# 307        27                                   EVN Baxter Krems
# 318        28     EVN Biomassefernheizwerk Mittleres Schwarzatal
# 868        78                              Knauf Werk Weißenbach
# 1044       94                            Montanwerke Brixlegg AG
# 1231      111  Saint-Gobian Rigips Austria GmbH, Werk Bad Aussee
# 1231                 Saint-Gobain Rigips Austria GesmbH
# 1407    Styromagnesit Steirische Magnesitindustrie GmbH
# 1440                           GAS CONNECT AUSTRIA GmbH
# 1451                           GAS CONNECT AUSTRIA GmbH
# 1462                           GAS CONNECT AUSTRIA GmbH
# 1473                           GAS CONNECT AUSTRIA GmbH
# 1484                           GAS CONNECT AUSTRIA GmbH
# 1638                 VERBUND Thermal Power GmbH & CO KG
# 1693                           GAS CONNECT AUSTRIA GmbH
# 1704                           GAS CONNECT AUSTRIA GmbH
# 1715                           GAS CONNECT AUSTRIA GmbH
# 2045                         Böhler Bleche GmbH & Co KG
# 2056                          voestalpine Schienen GmbH
# 2067                  voestalpine Tubulars GmbH & Co KG
# 2078                     voestalpine Austria Draht GmbH
# 2089                                 Bunge Austria GmbH
# ...                                                 ...
# 25432           TOTAL Raffinerie Mitteldeutschland GmbH
# 2453                              ArcelorMittal Belgium
# 89463                                        Sarlux Srl
# 111210                Polski Koncern Naftowy ORLEN S.A.
# 27445               ArcelorMittal Eisenhüttenstadt GmbH
# 5247                       Total Raffinaderij Antwerpen
# 27148                                     RUHR OEL GmbH
# 123816                                     SSAB EMEA AB
# 2640                                 B.A.S.F. Antwerpen
# 114862                       SC ARCELORMITTAL GALATI SA
# 101420                SHELL Nederland Raffinaderij B.V.
# 52250                                  Ruukki Metals Oy
# 10054                         TŘINECKÉ ŽELEZÁRNY, a. s.
# 14685                         ArcelorMittal Bremen GmbH
# 111848                        ArcelorMittal Poland S.A.
# 2442                              ArcelorMittal Belgium
# 7447                         ArcelorMittal Ostrava a.s.
# 17721                        Salzgitter Flachstahl GmbH
# 74239                             Tata Steel UK Limited
# 73315                             Tata Steel UK Limited
# 27456              ROGESA Roheisengesellschaft Saar mbH
# 128062                       U. S. Steel Košice, s.r.o.
# 1672                             voestalpine Stahl GmbH
# 54890                                         BERSILLON
# 17710                 Hüttenwerke Krupp Mannesmann GmbH
# 36542                        ARCELORMITTAL ESPAÑA, S.A.
# 55374                                         BERSILLON
# 101794                         Tata Steel IJmuiden B.V.
# 89089                                       ILVA S.P.A.
# 22407                      ThyssenKrupp Steel Europe AG
#
#                                             ACTIVITY_TYPE  \
# 65                      PRODUCTION_OF_SECONDARY_ALUMINIUM
# 76         PRODUCTION_OR_PROCESSING_OF_NON_FERROUS_METALS
# 98                   PRODUCTION_OF_BULK_ORGANIC_CHEMICALS
# 131       PRODUCTION_CEMENT_ROTARY_FURNACES_INSTALLATIONS
# 142       PRODUCTION_CEMENT_ROTARY_FURNACES_INSTALLATIONS
# 153       PRODUCTION_CEMENT_ROTARY_FURNACES_INSTALLATIONS
# 175                  COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 186            PRODUCTION_OR_PROCESSING_OF_FERROUS_METALS
# 197                                 PRODUCTION_OF_AMMONIA
# 208                             PRODUCTION_OF_NITRIC_ACID
# 307       COMBUSTION_INSTALLATIONS_THERMAL_MORE_TWENTY_MW
# 318                  COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 868     DRYING_OR_CALCINATION_OF_GYPSUM_OR_PRODUCTION_...
# 1044       PRODUCTION_OR_PROCESSING_OF_NON_FERROUS_METALS
# 1231    DRYING_OR_CALCINATION_OF_GYPSUM_OR_PRODUCTION_...
# 1407                   PRODUCTION_OF_LIME_OR_CALCINATION_
# 1440                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1451                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1462                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1473                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1484                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1638                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1693                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1704                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1715                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 2045           PRODUCTION_OR_PROCESSING_OF_FERROUS_METALS
# 2056           PRODUCTION_OR_PROCESSING_OF_FERROUS_METALS
# 2067           PRODUCTION_OR_PROCESSING_OF_FERROUS_METALS
# 2078           PRODUCTION_OR_PROCESSING_OF_FERROUS_METALS
# 2089                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# ...                                                   ...
# 25432                              MINERAL_OIL_REFINERIES
# 2453                      PRODUCTION_OF_PIG_IRON_OR_STEEL
# 89463                             REFINING_OF_MINERAL_OIL
# 111210                            REFINING_OF_MINERAL_OIL
# 27445   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 5247                               MINERAL_OIL_REFINERIES
# 27148                              MINERAL_OIL_REFINERIES
# 123816  PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 2640                 COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 114862               COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 101420                             MINERAL_OIL_REFINERIES
# 52250   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 10054   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 14685   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 111848                    PRODUCTION_OF_PIG_IRON_OR_STEEL
# 2442                                   PRODUCTION_OF_COKE
# 7447      COMBUSTION_INSTALLATIONS_THERMAL_MORE_TWENTY_MW
# 17721   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 74239                                          COKE_OVENS
# 73315                                          COKE_OVENS
# 27456   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 128062               COMBUSTION_OF_FUELS_IN_INSTALLATIONS
# 1672                      PRODUCTION_OF_PIG_IRON_OR_STEEL
# 54890   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 17710   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 36542   PRODUCTION_PIG_IRON_STEEL_CONT_CASTING_INSTALL...
# 1672           Austria  48.278607  14.319792  2018     6227879
# 54890           France  43.437882   4.945711  2018     6246659
# 17710          Germany  51.370264   6.726661  2018     6300567
# 36542            Spain  43.541185  -5.725274  2018     6760101
# 55374           France  51.041846   2.373328  2018     8639626
# 101794     Netherlands  52.473966   4.622399  2018     9727505
# 89089            Italy  40.491998  17.214706  2018    12151525
# 22407          Germany  51.491149   6.743368  2018    15356688
#
#         ALLOCATION_RESERVE  ALLOCATION_TRANSITIONAL  VERIFIED_EMISSIONS  BIN
# 65                       1                        1                   1    6
# 76                       1                        1                   1    6
# 98                       1                        1                   1    6
# 131                      1                        1                   1    6
# 142                      1                        1                   1    6
# 153                      1                        1                   1    6
# 175                      1                        1                 500    6
# 186                      1                        1                   1    6
# 197                      1                        1                   1    6
# 208                      1                        1                   1    6
# 307                      1                        1                   1    6
# 318                      1                        1                   1    6
# 868                      1                        1                   1    6
# 1044                     1                        1                   1    6
# 1231                     1                        1                   1    6
# 1407                     1                        1                   1    6
# 1440                     1                        1                   1    6
# 1451                     1                        1                   1    6
# 1462                     1                        1                   1    6
# 1473                     1                        1                   1    6
# 1484                     1                        1                   1    6
# 1638                     1                        1                   1    6
# 1693                     1                        1                   1    6
# 1704                     1                        1                   1    6
# 1715                     1                        1                   1    6
# 2045                     1                        1                   1    6
# 2056                     1                        1                   1    6
# 2067                     1                        1                   1    6
# 2078                     1                        1                   1    6
# 2089                     1                        1                   1    6
# ...                    ...                      ...                 ...  ...
# 25432                    1                        1             2135154    1
# 2453                210237                        1                   1    1
# 89463                    1                        1             6348594    1
# 111210                   1                        1             2663180    1
# 27445                    1                        1             1446767    1
# 5247                     1                        1             3643252    1
# 27148                    1                        1             2858225    1
# 123816                   1                        1             1058183    1
# 2640                     1                        1             3127531    1
# 114862                   1                        1             4104923    1
# 101420                   1                        1             4210638    1
# 52250                    1                        1             4025353    1
# 10054                    1                        1             2696598    1
# 14685                    1                        1             2621007    1
# 111848                   1                        1             2427068    1
# 2442                342339                        1             4461978    1
# 7447                     1                        1             2868088    1
# 17721                    1                        1             4359562    1
# 74239                    1                        1             5073764    1
# 73315               687437                        1             5814379    1
# 27456                    1                        1             4683105    1
# 128062                   1                        1             5969066    1
# 1672                     1                        1             7816077    1
# 54890                    1                        1             7460796    1
# 17710               261592                        1             4899207    1
# 36542                    1                        1             5646785    1
# 55374                    1                        1             8052937    1
# 101794                   1                        1             6512377    1
# 89089                    1                        1                   1    1
# 22407                    1                        1             8336515    1
#
# [128370 rows x 15 columns]

# %%
df.loc[df[value] < center,'BIN'] = pd.qcut(df[df[value] < center].groupby(['YEAR'])[value].rank(method='first'),
        q=5, retbins=False, labels=[6,7,8,9,10])

# %%
df.loc[df[value] >= 0,'BIN'] = pd.qcut(df.loc[df[value] >= 0,value].rank(method='first'), q=6, retbins=True, labels=[1,2,3,4,5], duplicates='drop')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-406-923f01c72596> in <module>
# ----> 1 df.loc[df[value] >= 0,'BIN'] = pd.qcut(df.loc[df[value] >= 0,value].rank(method='first'), q=6, retbins=True, labels=[1,2,3,4,5], duplicates='drop')
#
# /usr/local/anaconda3/envs/propulsion_env/lib/python3.7/site-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     304     fac, bins = _bins_to_cuts(x, bins, labels=labels,
#     305                               precision=precision, include_lowest=True,
# --> 306                               dtype=dtype, duplicates=duplicates)
#     307
#     308     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# /usr/local/anaconda3/envs/propulsion_env/lib/python3.7/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     351         else:
#     352             if len(labels) != len(bins) - 1:
# --> 353                 raise ValueError('Bin labels must be one fewer than '
#     354                                  'the number of bin edges')
#     355         if not is_categorical_dtype(labels):
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %%
df.loc[df[value] >= 0,'BIN'] = pd.qcut(df.loc[df[value] >= 0,value], q=6, retbins=True, labels=[1,2,3,4,5], duplicates='drop')
df.loc[df[value] < 0,'BIN'] = pd.qcut(df.loc[df[value] < 0,value], q=6, retbins=True, labels=[6,7,8,9,10], duplicates='drop')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-403-e35917e964d0> in <module>
# ----> 1 df.loc[df[value] >= 0,'BIN'] = pd.qcut(df.loc[df[value] >= 0,value], q=6, retbins=True, labels=[1,2,3,4,5], duplicates='drop')
#       2 df.loc[df[value] < 0,'BIN'] = pd.qcut(df.loc[df[value] < 0,value], q=6, retbins=True, labels=[6,7,8,9,10], duplicates='drop')
#
# /usr/local/anaconda3/envs/propulsion_env/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
#     191     def _validate_key(self, key, axis):
#
# /usr/local/anaconda3/envs/propulsion_env/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     364                         new_indexer = convert_from_missing_indexer_tuple(
#     365                             indexer, self.obj.axes)
# --> 366                         self._setitem_with_indexer(new_indexer, value)
#     367
#     368                         return self.obj
#
# /usr/local/anaconda3/envs/propulsion_env/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     604
#     605                     if len(labels) != len(value):
# --> 606                         raise ValueError('Must have equal len keys and value '
#     607                                          'when setting with an iterable')
#     608
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
data_02[data_02['INSTALLATION_NAME']=='Sunin lämpökeskus']
# Out:
#        INSTALLATION_NAME    ACCOUNT_HOLDER_NAME   ACTIVITY_TYPE CONTACT_CITY  \
# 52976  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52977  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52978  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52979  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52980  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52981  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52982  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52983  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52984  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52985  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
# 52986  Sunin lämpökeskus  Loimaan Kaukolämpö Oy  OTHER_ACTIVITY          nan
#
#       CONTACT_ADDRESS_L1  COUNTRY  LAT  LON  YEAR  ALLOCATION  \
# 52976        Linjakatu 2  Finland  0.0  0.0  2018           1
# 52977        Linjakatu 2  Finland  0.0  0.0  2017           1
# 52978        Linjakatu 2  Finland  0.0  0.0  2016           1
# 52979        Linjakatu 2  Finland  0.0  0.0  2015         206
# 52980        Linjakatu 2  Finland  0.0  0.0  2014         931
# 52981        Linjakatu 2  Finland  0.0  0.0  2013        1040
# 52982        Linjakatu 2  Finland  0.0  0.0  2012           1
# 52983        Linjakatu 2  Finland  0.0  0.0  2011           1
# 52984        Linjakatu 2  Finland  0.0  0.0  2010           1
# 52985        Linjakatu 2  Finland  0.0  0.0  2009           1
# 52986        Linjakatu 2  Finland  0.0  0.0  2008           1
#
#        ALLOCATION_RESERVE  ALLOCATION_TRANSITIONAL  VERIFIED_EMISSIONS
# 52976                   1                        1                  77
# 52977                   1                        1                 167
# 52978                   1                        1                  65
# 52979                   1                        1                  35
# 52980                   1                        1                 224
# 52981                   1                        1                  58
# 52982                   1                        1                1153
# 52983                   1                        1                 875
# 52984                   1                        1                2347
# 52985                   1                        1                1660
# 52986                   1                        1                 447

# %%
'ALLOCATION_2018',
'ALLOCATION_RESERVE_2018',
'ALLOCATION_TRANSITIONAL_2018',
'VERIFIED_EMISSIONS_2018',

'ALLOCATION_2017',
'ALLOCATION_RESERVE_2017',
'ALLOCATION_TRANSITIONAL_2017',
'VERIFIED_EMISSIONS_2017',

'ALLOCATION_2016',
'ALLOCATION_RESERVE_2016',
'ALLOCATION_TRANSITIONAL_2016',
'VERIFIED_EMISSIONS_2016',

'ALLOCATION_2015',
'ALLOCATION_RESERVE_2015',
'ALLOCATION_TRANSITIONAL_2015',
'VERIFIED_EMISSIONS_2015',

'ALLOCATION_2014',
'ALLOCATION_RESERVE_2014',
'ALLOCATION_TRANSITIONAL_2014',
'VERIFIED_EMISSIONS_2014',

'ALLOCATION_2013',
'ALLOCATION_RESERVE_2013',
'ALLOCATION_TRANSITIONAL_2013',
'VERIFIED_EMISSIONS_2013',



'ALLOCATION_2012',
'VERIFIED_EMISSIONS_2012',

'ALLOCATION_2011',
'VERIFIED_EMISSIONS_2011',

'ALLOCATION_2010',
'VERIFIED_EMISSIONS_2010',

'ALLOCATION_2009',
'VERIFIED_EMISSIONS_2009',

'ALLOCATION_2008',
'VERIFIED_EMISSIONS_2008',
